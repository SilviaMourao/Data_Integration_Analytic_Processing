# %%
import psycopg2 as pg
import pandas as pd
import os

# %%
#Read file
df=pd.read_excel("area.xlsx")
df
# Out:
#               Country Name          1961          1962          1963  \
# 0                  Albania  2.740000e+04  2.740000e+04  2.740000e+04
# 1                  Andorra  4.700000e+02  4.700000e+02  4.700000e+02
# 2                  Armenia  2.847000e+04  2.847000e+04  2.847000e+04
# 3                Australia  7.682300e+06  7.682300e+06  7.682300e+06
# 4                  Austria  8.258000e+04  8.258000e+04  8.258000e+04
# 5               Azerbaijan  8.321700e+04  8.321700e+04  8.321700e+04
# 6                  Belgium  3.282000e+04  3.282000e+04  3.282000e+04
# 7                 Bulgaria  1.106300e+05  1.106300e+05  1.106300e+05
# 8   Bosnia and Herzegovina  5.120000e+04  5.120000e+04  5.120000e+04
# 9                  Belarus  2.028400e+05  2.028400e+05  2.028400e+05
# 10                 Bolivia  1.083300e+06  1.083300e+06  1.083300e+06
# 11             Switzerland  3.952800e+04  3.952800e+04  3.952800e+04
# 12                  Cyprus  9.240000e+03  9.240000e+03  9.240000e+03
# ...

# %%
df1 = pd.melt(df, id_vars = ["Country Name"])
df1
# Out:
#          Country Name variable      value
# 0             Albania     1961    27400.0
# 1             Andorra     1961      470.0
# 2             Armenia     1961    28470.0
# 3           Australia     1961  7682300.0
# 4             Austria     1961    82580.0
# ...               ...      ...        ...
# 3045  Slovak Republic     2021    48080.0
# 3046         Slovenia     2021    20136.4
# 3047           Sweden     2021   407310.0
# 3048           Turkey     2021   769630.0
# 3049          Ukraine     2021   579400.0
#
# [3050 rows x 3 columns]

# %%
df1['value'] = df1.value.replace('NaN','')

# %%
df1.to_csv('Area.csv')
